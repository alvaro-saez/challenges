# %% [markdown]
# ## Collaborative Project 1

# %%
import pandas as pd
import requests
import bs4
import numpy as np
import re
import lxml

# %%
url_wk = "https://en.wikipedia.org/wiki/List_of_Nobel_laureates"

# %%
url_wk_response = requests.get(url_wk).content

# %%
parsed_wk_main_table = bs4.BeautifulSoup(url_wk_response,"html.parser").find_all("table",{"class":"wikitable sortable"})[0]
#parsed_wk_main_table

# %%
names_columns = parsed_wk_main_table.find_all("tbody")[0].find_all("th")[0:7]
first_columns_list = [re.sub("\[a\]|\d|\[|\]","",i.text.strip()) for i in names_columns]
first_columns_list
# Out:
# ['Year',
#  'Physics',
#  'Chemistry',
#  'Physiologyor Medicine',
#  'Literature',
#  'Peace',
#  'Economics(The Sveriges Riksbank Prize)']

# %%
raws_value = parsed_wk_main_table.find_all("tbody")[0].find_all("tr")[1:]
raws_value_list = [i.text.replace("\n\n",",").strip() for i in raws_value]
raws_value_list_array = [i.split(",")[:7] for i in raws_value_list]

# %%
df = pd.DataFrame(raws_value_list_x,columns=first_columns_list)
df
# Out:
#      Year                                           Physics  \
# 0    1901                                   Wilhelm Röntgen
# 1    1902                     Hendrik Lorentz;Pieter Zeeman
# 2    1903          Henri Becquerel;Pierre Curie;Marie Curie
# 3    1904                                     Lord Rayleigh
# 4    1905                                    Philipp Lenard
# ..    ...                                               ...
# 117  2018      Arthur Ashkin;Gérard Mourou;Donna Strickland
# 118  2019        James Peebles; Michel Mayor; Didier Queloz
# 119  2020    Roger Penrose; Reinhard Genzel; Andrea M. Ghez
# 120  2021  Syukuro Manabe; Klaus Hasselmann; Giorgio Parisi
# 121  Year                                           Physics
#
#                                              Chemistry  \
# 0                         Jacobus Henricus van 't Hoff
# 1                                 Hermann Emil Fischer
# 2                                     Svante Arrhenius
# ...

# %%
array = np.array(raws_value_list).reshape(len(raws_value_list),1)
array
# Out:
# array([["1901,Wilhelm Röntgen,Jacobus Henricus van 't Hoff,Emil Adolf von Behring,Sully Prudhomme,Henry Dunant;Frédéric Passy,—"],
#        ['1902,Hendrik Lorentz;Pieter Zeeman,Hermann Emil Fischer,Ronald Ross,Theodor Mommsen,Élie Ducommun;Charles Albert Gobat,—'],
#        ['1903,Henri Becquerel;Pierre Curie;Marie Curie,Svante Arrhenius,Niels Ryberg Finsen,Bjørnstjerne Bjørnson,Randal Cremer,—'],
#        ['1904,Lord Rayleigh,William Ramsay,Ivan Pavlov,Frédéric Mistral;José Echegaray,Institut de Droit International,—'],
#        ['1905,Philipp Lenard,Adolf von Baeyer,Robert Koch,Henryk Sienkiewicz,Bertha von Suttner,—'],
#        ['1906,J. J. Thomson,Henri Moissan,Camillo Golgi;Santiago Ramón y Cajal,Giosuè Carducci,Theodore Roosevelt,—'],
#        ['1907,Albert Abraham Michelson,Eduard Buchner,Charles Louis Alphonse Laveran,Rudyard Kipling,Ernesto Teodoro Moneta;Louis Renault,—'],
# ...

# %% [markdown]
# ### Otra forma más rápida de jugar con tablas de webs

# %%
wk_pd = pd.read_html(url_wk_response)[0].iloc[:121,:]
wk_pd
# Out:
#      Year                                           Physics  \
# 0    1901                                   Wilhelm Röntgen
# 1    1902                     Hendrik Lorentz;Pieter Zeeman
# 2    1903          Henri Becquerel;Pierre Curie;Marie Curie
# 3    1904                                     Lord Rayleigh
# 4    1905                                    Philipp Lenard
# ..    ...                                               ...
# 116  2017              Rainer Weiss;Barry Barish;Kip Thorne
# 117  2018      Arthur Ashkin;Gérard Mourou;Donna Strickland
# 118  2019        James Peebles; Michel Mayor; Didier Queloz
# 119  2020    Roger Penrose; Reinhard Genzel; Andrea M. Ghez
# 120  2021  Syukuro Manabe; Klaus Hasselmann; Giorgio Parisi
#
#                                              Chemistry  \
# 0                         Jacobus Henricus van 't Hoff
# 1                                 Hermann Emil Fischer
# 2                                     Svante Arrhenius
# ...
