# %% [markdown]
# # Team Pandas Dataframe

# %%
# imports
import numpy as np
import pandas as pd
import datetime

# %% [markdown]
# ---

# %% [markdown]
# ### Kombat 1: How to create a series from a list, numpy array and dict?
#
# Create a pandas series from each of the items below: a list, numpy and a dictionary

# %%
# Your code 

mylist = list('fghij')
myarr = np.arange(5,10)
mydict = dict(zip(mylist, myarr))

# %%
# Solution

print(mylistserie)
print(myarrserie)
print(mydictserie)
# Out:
# 0    f
# 1    g
# 2    h
# 3    i
# 4    j
# dtype: object
# 0    5
# 1    6
# 2    7
# 3    8
# 4    9
# dtype: int32
# f    5
# g    6
# h    7
# i    8
# j    9
# dtype: int32

# %%
mylist_pd = pd.Series(mylist)
myarr_pd = pd.Series(myarr)
mydict_pd = pd.Series(mydict)

# %% [markdown]
# ---

# %% [markdown]
# ### Kombat 2: How to combine many series to form a dataframe?
#
# Combine ser1 and ser2 to form a dataframe.

# %%
# Your code

ser1 = pd.Series(list('klmnopqrst'))
ser2 = pd.Series(np.arange(10))

pd.concat([ser1,ser2], axis=1)
# Out:
#    0  1
# 0  k  0
# 1  l  1
# 2  m  2
# 3  n  3
# 4  o  4
# 5  p  5
# 6  q  6
# 7  r  7
# 8  s  8
# 9  t  9

# %% [markdown]
# ---

# %% [markdown]
# ### Kombat 3: How to get the items not common to both series A and series B?
#
# Get all items of ser1 and ser2 not common to both.

# %%
# Your code
ser1 = pd.Series([1, 2, 3, 4, 5])
ser2 = pd.Series([4, 5, 6, 7, 8])

# union of the series
union = pd.Series(np.union1d(ser1, ser2))

# intersection of the series
intersect = pd.Series(np.intersect1d(ser1, ser2))

# uncommon elements in both the series 
notcommonseries = union[~union.isin(intersect)]

notcommonseries
# Out:
# 0    1
# 1    2
# 2    3
# 5    6
# 6    7
# 7    8
# dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# ### Kombat 4: How to extract items at given positions from a series
#
# From ser, extract the items at positions in list pos.

# %%
# Your code

ser = pd.Series(list('abcdefghijklmnopqrstuvwxyz'))
pos = [0, 4, 8, 14, 20]

ser[pos]
# Out:
# 0     a
# 4     e
# 8     i
# 14    o
# 20    u
# dtype: object

# %% [markdown]
# ---

# %% [markdown]
# ### Kombat 5: How to create a TimeSeries starting ‘2022-01-01’ and 10 weekends (saturdays) after that, having random numbers as values?

# %%
# Your code

time_series = pd.Series(np.random.randint(1, 10, 10), )

time_series
# Out:
# 0    9
# 1    6
# 2    3
# 3    6
# 4    5
# 5    7
# 6    2
# 7    4
# 8    6
# 9    6
# dtype: int32

# %% [markdown]
# ---

# %%
ti = pd.date_range("2022-01-01", periods=10, freq="W-SAT")
# Out:
# DatetimeIndex(['2022-01-01', '2022-01-08', '2022-01-15', '2022-01-22',
#                '2022-01-29', '2022-02-05', '2022-02-12', '2022-02-19',
#                '2022-02-26', '2022-03-05'],
#               dtype='datetime64[ns]', freq='W-SAT')

# %%
tim_series_alvaro = pd.Series((np.random.randint(1, 10, 10)), index=ti)
tim_series_alvaro
# Out:
# 2022-01-01    2
# 2022-01-08    6
# 2022-01-15    5
# 2022-01-22    9
# 2022-01-29    4
# 2022-02-05    1
# 2022-02-12    9
# 2022-02-19    5
# 2022-02-26    7
# 2022-03-05    2
# Freq: W-SAT, dtype: int32

# %% [markdown]
# ### Kombat 6: How to import only every nth row from a csv file to create a dataframe?
#
# Import every 50th row of BostonHousing dataset as a dataframe.

# %%
# Your code

url6 = 'https://raw.githubusercontent.com/selva86/datasets/master/BostonHousing.csv'


df_alvaro_6 = pd.read_csv(url6)
df_alvaro_6
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
alvaro_6_list = np.arange(0,len(df_alvaro_6),50)
alvaro_6_list
# Out:
# array([  0,  50, 100, 150, 200, 250, 300, 350, 400, 450, 500])

# %%
df_alvaro_6.iloc[alvaro_6_list,:]
# Out:
#          crim    zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 0     0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296
# 50    0.08873  21.0   5.64     0  0.439  5.963   45.7  6.8147    4  243
# 100   0.14866   0.0   8.56     0  0.520  6.727   79.9  2.7778    5  384
# 150   1.65660   0.0  19.58     0  0.871  6.122   97.3  1.6180    5  403
# 200   0.01778  95.0   1.47     0  0.403  7.135   13.9  7.6534    3  402
# 250   0.14030  22.0   5.86     0  0.431  6.487   13.0  7.3967    7  330
# 300   0.04417  70.0   2.24     0  0.400  6.871   47.4  7.8278    5  358
# 350   0.06211  40.0   1.25     0  0.429  6.490   44.4  8.7921    1  335
# 400  25.04610   0.0  18.10     0  0.693  5.987  100.0  1.5888   24  666
# 450   6.71772   0.0  18.10     0  0.713  6.749   92.6  2.3236   24  666
# 500   0.22438   0.0   9.69     0  0.585  6.027   79.7  2.4982    6  391
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 50      16.8  395.56  13.45  19.7
# 100     20.9  394.76   9.42  27.5
# 150     14.7  372.80  14.10  21.5
# 200     17.0  384.30   4.45  32.9
# 250     19.1  396.28   5.90  24.4
# 300     14.8  390.86   6.07  24.8
# 350     19.7  396.90   5.98  22.9
# 400     20.2  396.90  26.77   5.6
# 450     20.2    0.32  17.44  13.4
# 500     19.2  396.90  14.33  16.8

# %% [markdown]
# ---

# %% [markdown]
# ### Kombat 7: How to import only specified columns from a csv file?
#
# Import ‘crim’ and ‘medv’ columns of the BostonHousing dataset as a dataframe.

# %%
# Your code

url7 = 'https://raw.githubusercontent.com/selva86/datasets/master/BostonHousing.csv'

# %%
df_alvaro_7 = pd.read_csv(url7)
df_alvaro_7
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
# Solution 

df_alvaro_7[["crim","medv"]]
# Out:
#         crim  medv
# 0    0.00632  24.0
# 1    0.02731  21.6
# 2    0.02729  34.7
# 3    0.03237  33.4
# 4    0.06905  36.2
# ..       ...   ...
# 501  0.06263  22.4
# 502  0.04527  20.6
# 503  0.06076  23.9
# 504  0.10959  22.0
# 505  0.04741  11.9
#
# [506 rows x 2 columns]

# %% [markdown]
# ---

# %% [markdown]
# ### Kombat 8: How to slice a DataFrame by column value?
#
# Get every Ford car with a Horsepower greater than 100 from the Cars93 dataset.

# %%
# Your code

url8 = 'https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv'

df_alvaro_8 = pd.read_csv(url8)
df_alvaro_8
# Out:
#    Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0         Acura  Integra    Small       12.9   15.9       18.8      25.0
# 1           NaN   Legend  Midsize       29.2   33.9       38.7      18.0
# 2          Audi       90  Compact       25.9   29.1       32.3      20.0
# 3          Audi      100  Midsize        NaN   37.7       44.6      19.0
# 4           BMW     535i  Midsize        NaN   30.0        NaN      22.0
# ..          ...      ...      ...        ...    ...        ...       ...
# 88   Volkswagen  Eurovan      Van       16.6   19.7       22.7      17.0
# 89   Volkswagen   Passat  Compact       17.6   20.0       22.4      21.0
# 90   Volkswagen  Corrado   Sporty       22.9   23.3       23.7      18.0
# 91        Volvo      240  Compact       21.8   22.7       23.5      21.0
# 92          NaN      850  Midsize       24.8   26.7       28.5      20.0
#
#     MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# 0          31.0                None      Front  ...        5.0   177.0
# 1          25.0  Driver & Passenger      Front  ...        5.0   195.0
# 2          26.0         Driver only      Front  ...        5.0   180.0
# 3          26.0  Driver & Passenger        NaN  ...        6.0   193.0
# 4          30.0                 NaN       Rear  ...        4.0   186.0
# ..          ...                 ...        ...  ...        ...     ...
# 88         21.0                None      Front  ...        7.0   187.0
# 89         30.0                None      Front  ...        5.0   180.0
# 90         25.0                None      Front  ...        4.0   159.0
# 91         28.0         Driver only       Rear  ...        5.0   190.0
# 92         28.0  Driver & Passenger      Front  ...        5.0   184.0
#
#     Wheelbase  Width  Turn.circle Rear.seat.room  Luggage.room  Weight  \
# 0       102.0   68.0         37.0           26.5           NaN  2705.0
# 1       115.0   71.0         38.0           30.0          15.0  3560.0
# 2       102.0   67.0         37.0           28.0          14.0  3375.0
# 3       106.0    NaN         37.0           31.0          17.0  3405.0
# 4       109.0   69.0         39.0           27.0          13.0  3640.0
# ..        ...    ...          ...            ...           ...     ...
# 88      115.0   72.0         38.0           34.0           NaN  3960.0
# 89      103.0   67.0         35.0           31.5          14.0  2985.0
# 90       97.0   66.0         36.0           26.0          15.0  2810.0
# 91      104.0   67.0         37.0           29.5          14.0  2985.0
# 92      105.0   69.0         38.0           30.0          15.0  3245.0
#
#      Origin                Make
# 0   non-USA       Acura Integra
# 1   non-USA        Acura Legend
# 2   non-USA             Audi 90
# 3   non-USA            Audi 100
# 4   non-USA            BMW 535i
# ..      ...                 ...
# 88      NaN  Volkswagen Eurovan
# 89  non-USA   Volkswagen Passat
# 90  non-USA  Volkswagen Corrado
# 91  non-USA           Volvo 240
# 92  non-USA           Volvo 850
#
# [93 rows x 27 columns]

# %%
df_alvaro_8[(df_alvaro_8["Manufacturer"]=="Ford") & (df_alvaro_8["Horsepower"]>100)]
# Out:
#    Manufacturer           Model    Type  Min.Price  Price  Max.Price  \
# 31         Ford          Escort   Small        8.4   10.1       11.9
# 33         Ford         Mustang  Sporty       10.8   15.9       21.0
# 34         Ford           Probe  Sporty       12.8   14.0       15.2
# 35         Ford        Aerostar     Van       14.5   19.9       25.3
# 37         Ford  Crown_Victoria   Large       20.1   20.9       21.7
#
#     MPG.city  MPG.highway      AirBags DriveTrain  ... Passengers  Length  \
# 31      23.0         30.0         None      Front  ...        5.0   171.0
# 33      22.0         29.0  Driver only       Rear  ...        4.0   180.0
# 34       NaN         30.0  Driver only      Front  ...        4.0   179.0
# 35      15.0         20.0  Driver only        4WD  ...        7.0   176.0
# 37      18.0         26.0  Driver only       Rear  ...        6.0   212.0
#
#     Wheelbase  Width  Turn.circle Rear.seat.room  Luggage.room  Weight  \
# 31       98.0   67.0         36.0           28.0          12.0  2530.0
# 33      101.0   68.0         40.0           24.0          12.0     NaN
# 34      103.0   70.0         38.0           23.0          18.0  2710.0
# 35      119.0   72.0         45.0           30.0           NaN  3735.0
# 37      114.0   78.0         43.0           30.0          21.0  3950.0
#
#     Origin                 Make
# 31     USA          Ford Escort
# 33     USA         Ford Mustang
# 34     USA           Ford Probe
# 35     USA        Ford Aerostar
# 37     USA  Ford Crown_Victoria
#
# [5 rows x 27 columns]

# %% [markdown]
# ---

# %% [markdown]
# # FINISH HIM!!!
